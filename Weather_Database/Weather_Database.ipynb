# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather=city_weather['weather']
        city_weather_description = weather[0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hede
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | cordoba
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | banff
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | mehamn
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 1 | bubaque
# Processing Record 18 of Set 1 | evensk
# Processing Record 19 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | lagoa
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | pingliang
# Processing Record 25 of Set 1 | sambava
# Processing Record 26 of Set 1 | komsomolskiy
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | port-gentil
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 1 | nambour
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | svetlogorsk
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | nayoro
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | kargat
# Processing Record 43 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 44 of Set 1 | am timan
# Processing Record 45 of Set 1 | henties bay
# Processing Record 46 of Set 1 | hit
# Processing Record 47 of Set 1 | coihaique
# Processing Record 48 of Set 1 | batagay-alyta
# Processing Record 49 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | leninsk
# Processing Record 2 of Set 2 | gijon
# Processing Record 3 of Set 2 | cairns
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | acapulco
# Processing Record 11 of Set 2 | kavieng
# Processing Record 12 of Set 2 | kirovsk
# Processing Record 13 of Set 2 | imeni babushkina
# Processing Record 14 of Set 2 | vanimo
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | makakilo city
# Processing Record 18 of Set 2 | maumere
# Processing Record 19 of Set 2 | katakwi
# Processing Record 20 of Set 2 | marhaura
# Processing Record 21 of Set 2 | deputatskiy
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | ilam
# Processing Record 25 of Set 2 | talara
# Processing Record 26 of Set 2 | gamba
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | vanavara
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 2 | san cristobal
# Processing Record 34 of Set 2 | praia da vitoria
# Processing Record 35 of Set 2 | turukhansk
# Processing Record 36 of Set 2 | flinders
# Processing Record 37 of Set 2 | ransang
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | plonsk
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | haimen
# Processing Record 44 of Set 2 | portpatrick
# City not found. Skipping...
# Processing Record 45 of Set 2 | katete
# Processing Record 46 of Set 2 | kiunga
# Processing Record 47 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 48 of Set 2 | juneau
# Processing Record 49 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | fukue
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | mudgee
# Processing Record 8 of Set 3 | laguna
# Processing Record 9 of Set 3 | faya
# Processing Record 10 of Set 3 | chapais
# Processing Record 11 of Set 3 | roros
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | teluk nibung
# Processing Record 14 of Set 3 | manono
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | hualmay
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | korla
# Processing Record 19 of Set 3 | biak
# Processing Record 20 of Set 3 | zeya
# Processing Record 21 of Set 3 | port hardy
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | kollumerland
# City not found. Skipping...
# Processing Record 24 of Set 3 | salalah
# Processing Record 25 of Set 3 | egvekinot
# Processing Record 26 of Set 3 | nouadhibou
# Processing Record 27 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | machado
# Processing Record 30 of Set 3 | smalininkai
# Processing Record 31 of Set 3 | pevek
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | antofagasta
# Processing Record 34 of Set 3 | xining
# Processing Record 35 of Set 3 | mitsamiouli
# Processing Record 36 of Set 3 | kingisepp
# Processing Record 37 of Set 3 | stende
# Processing Record 38 of Set 3 | tezu
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | gizeh
# Processing Record 41 of Set 3 | tara
# Processing Record 42 of Set 3 | trinidad
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | mporokoso
# Processing Record 47 of Set 3 | pakdasht
# Processing Record 48 of Set 3 | da nang
# Processing Record 49 of Set 3 | ilembo
# Processing Record 50 of Set 3 | praia
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | mayumba
# Processing Record 3 of Set 4 | mogadishu
# Processing Record 4 of Set 4 | astipalaia
# City not found. Skipping...
# Processing Record 5 of Set 4 | digha
# Processing Record 6 of Set 4 | binabalian
# Processing Record 7 of Set 4 | tigil
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | tabas
# Processing Record 10 of Set 4 | channel-port aux basques
# Processing Record 11 of Set 4 | saint-augustin
# Processing Record 12 of Set 4 | road town
# Processing Record 13 of Set 4 | along
# Processing Record 14 of Set 4 | abha
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | lazaro cardenas
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | bacolod
# Processing Record 20 of Set 4 | namatanai
# Processing Record 21 of Set 4 | barrow
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | shar
# Processing Record 24 of Set 4 | raudeberg
# Processing Record 25 of Set 4 | tuatapere
# Processing Record 26 of Set 4 | worcester
# Processing Record 27 of Set 4 | zhigansk
# Processing Record 28 of Set 4 | diamantino
# Processing Record 29 of Set 4 | garowe
# Processing Record 30 of Set 4 | bukachacha
# Processing Record 31 of Set 4 | tahe
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | cayenne
# Processing Record 34 of Set 4 | bilma
# Processing Record 35 of Set 4 | arbazh
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | mwanza
# Processing Record 40 of Set 4 | ginda
# Processing Record 41 of Set 4 | shelburne
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | dalvik
# Processing Record 45 of Set 4 | khatanga
# Processing Record 46 of Set 4 | georgetown
# Processing Record 47 of Set 4 | fortuna
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | boca do acre
# Processing Record 50 of Set 4 | chimbote
# Processing Record 1 of Set 5 | dunhua
# Processing Record 2 of Set 5 | derzhavinsk
# Processing Record 3 of Set 5 | rio grande
# Processing Record 4 of Set 5 | bedele
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | nome
# Processing Record 8 of Set 5 | vila franca do campo
# Processing Record 9 of Set 5 | fairbanks
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | sayyan
# Processing Record 12 of Set 5 | ballina
# Processing Record 13 of Set 5 | shubarshi
# Processing Record 14 of Set 5 | atka
# City not found. Skipping...
# Processing Record 15 of Set 5 | cefalu
# Processing Record 16 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 17 of Set 5 | port macquarie
# Processing Record 18 of Set 5 | peniche
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | kruisfontein
# Processing Record 22 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 5 | xuddur
# Processing Record 24 of Set 5 | santa catarina de tepehuanes
# Processing Record 25 of Set 5 | bathsheba
# Processing Record 26 of Set 5 | berbera
# Processing Record 27 of Set 5 | merrill
# Processing Record 28 of Set 5 | grande prairie
# Processing Record 29 of Set 5 | tavda
# Processing Record 30 of Set 5 | cuamba
# Processing Record 31 of Set 5 | tautira
# Processing Record 32 of Set 5 | qui nhon
# Processing Record 33 of Set 5 | usinsk
# Processing Record 34 of Set 5 | provideniya
# Processing Record 35 of Set 5 | sur
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | rocha
# Processing Record 38 of Set 5 | valentin gomez farias
# Processing Record 39 of Set 5 | isetskoye
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | yar-sale
# Processing Record 42 of Set 5 | hobart
# Processing Record 43 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | aviles
# Processing Record 46 of Set 5 | tucurui
# Processing Record 47 of Set 5 | bandarbeyla
# Processing Record 48 of Set 5 | safaga
# Processing Record 49 of Set 5 | port elizabeth
# Processing Record 50 of Set 5 | benghazi
# Processing Record 1 of Set 6 | mayo
# Processing Record 2 of Set 6 | champerico
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | lanark
# Processing Record 5 of Set 6 | tasiilaq
# Processing Record 6 of Set 6 | greenfield
# Processing Record 7 of Set 6 | sobolevo
# Processing Record 8 of Set 6 | baruun-urt
# Processing Record 9 of Set 6 | kormilovka
# Processing Record 10 of Set 6 | oussouye
# Processing Record 11 of Set 6 | klaksvik
# Processing Record 12 of Set 6 | banda aceh
# Processing Record 13 of Set 6 | ust-tsilma
# Processing Record 14 of Set 6 | xiangdong
# City not found. Skipping...
# Processing Record 15 of Set 6 | puerto narino
# Processing Record 16 of Set 6 | kirakira
# Processing Record 17 of Set 6 | lompoc
# Processing Record 18 of Set 6 | kaa-khem
# Processing Record 19 of Set 6 | srandakan
# Processing Record 20 of Set 6 | hobyo
# Processing Record 21 of Set 6 | ilulissat
# Processing Record 22 of Set 6 | dayong
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | kyra
# Processing Record 25 of Set 6 | olafsvik
# Processing Record 26 of Set 6 | iqaluit
# Processing Record 27 of Set 6 | sijunjung
# Processing Record 28 of Set 6 | nhulunbuy
# Processing Record 29 of Set 6 | moussoro
# Processing Record 30 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 6 | kununurra
# Processing Record 32 of Set 6 | grand-santi
# Processing Record 33 of Set 6 | arlit
# Processing Record 34 of Set 6 | mkushi
# Processing Record 35 of Set 6 | imeni zhelyabova
# Processing Record 36 of Set 6 | el guapinol
# Processing Record 37 of Set 6 | khor
# Processing Record 38 of Set 6 | andenes
# Processing Record 39 of Set 6 | barabai
# Processing Record 40 of Set 6 | neder vindinge
# Processing Record 41 of Set 6 | ouidah
# Processing Record 42 of Set 6 | daru
# Processing Record 43 of Set 6 | high level
# Processing Record 44 of Set 6 | abbeville
# Processing Record 45 of Set 6 | kavali
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | burgeo
# Processing Record 48 of Set 6 | yerbogachen
# Processing Record 49 of Set 6 | hervey bay
# Processing Record 50 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 7 | galesong
# Processing Record 2 of Set 7 | naica
# Processing Record 3 of Set 7 | saint george
# Processing Record 4 of Set 7 | sola
# Processing Record 5 of Set 7 | aberystwyth
# Processing Record 6 of Set 7 | carnarvon
# Processing Record 7 of Set 7 | caravelas
# Processing Record 8 of Set 7 | agva
# City not found. Skipping...
# Processing Record 9 of Set 7 | mulchen
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | changji
# Processing Record 12 of Set 7 | rauma
# Processing Record 13 of Set 7 | mokokchung
# Processing Record 14 of Set 7 | ixtapa
# Processing Record 15 of Set 7 | kangaatsiaq
# Processing Record 16 of Set 7 | qaanaaq
# Processing Record 17 of Set 7 | banyumas
# Processing Record 18 of Set 7 | zehdenick
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | gladstone
# Processing Record 21 of Set 7 | dandong
# Processing Record 22 of Set 7 | half moon bay
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | kikwit
# Processing Record 25 of Set 7 | puerto colombia
# Processing Record 26 of Set 7 | avera
# Processing Record 27 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | gornopravdinsk
# Processing Record 29 of Set 7 | chuy
# Processing Record 30 of Set 7 | mitu
# Processing Record 31 of Set 7 | karabulak
# Processing Record 32 of Set 7 | wasilla
# Processing Record 33 of Set 7 | siguiri
# Processing Record 34 of Set 7 | yenagoa
# Processing Record 35 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | husavik
# Processing Record 37 of Set 7 | pacific grove
# Processing Record 38 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 7 | taoudenni
# Processing Record 40 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 41 of Set 7 | hansi
# Processing Record 42 of Set 7 | san francisco
# Processing Record 43 of Set 7 | san policarpo
# Processing Record 44 of Set 7 | shiraz
# Processing Record 45 of Set 7 | hofn
# Processing Record 46 of Set 7 | moroni
# Processing Record 47 of Set 7 | marienburg
# Processing Record 48 of Set 7 | tibiri
# Processing Record 49 of Set 7 | pedernales
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | aldan
# Processing Record 2 of Set 8 | newport
# Processing Record 3 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 8 | imbituba
# Processing Record 5 of Set 8 | oranjemund
# Processing Record 6 of Set 8 | bid
# City not found. Skipping...
# Processing Record 7 of Set 8 | sungai siput utara
# City not found. Skipping...
# Processing Record 8 of Set 8 | cascais
# Processing Record 9 of Set 8 | dire dawa
# Processing Record 10 of Set 8 | bela
# Processing Record 11 of Set 8 | moengo
# Processing Record 12 of Set 8 | anadyr
# Processing Record 13 of Set 8 | lorengau
# Processing Record 14 of Set 8 | noshiro
# Processing Record 15 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 8 | shenjiamen
# Processing Record 17 of Set 8 | turbat
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | moron
# Processing Record 20 of Set 8 | namwala
# Processing Record 21 of Set 8 | ndele
# Processing Record 22 of Set 8 | berlevag
# Processing Record 23 of Set 8 | richards bay
# Processing Record 24 of Set 8 | damghan
# Processing Record 25 of Set 8 | mmabatho
# Processing Record 26 of Set 8 | verkhoyansk
# Processing Record 27 of Set 8 | marawi
# Processing Record 28 of Set 8 | muriwai beach
# Processing Record 29 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | erenhot
# Processing Record 31 of Set 8 | livingston
# Processing Record 32 of Set 8 | smirnykh
# Processing Record 33 of Set 8 | mormugao
# Processing Record 34 of Set 8 | belmonte
# Processing Record 35 of Set 8 | dromolaxia
# Processing Record 36 of Set 8 | kemijarvi
# Processing Record 37 of Set 8 | goderich
# Processing Record 38 of Set 8 | les cayes
# Processing Record 39 of Set 8 | akyab
# Processing Record 40 of Set 8 | talca
# Processing Record 41 of Set 8 | qeshm
# Processing Record 42 of Set 8 | sandpoint
# Processing Record 43 of Set 8 | khorixas
# Processing Record 44 of Set 8 | pangnirtung
# Processing Record 45 of Set 8 | hanzhong
# Processing Record 46 of Set 8 | mount isa
# Processing Record 47 of Set 8 | san quintin
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | karang tengah
# Processing Record 50 of Set 8 | walvis bay
# Processing Record 1 of Set 9 | surt
# Processing Record 2 of Set 9 | denpasar
# Processing Record 3 of Set 9 | gorkovskoye
# City not found. Skipping...
# Processing Record 4 of Set 9 | naugarzan
# City not found. Skipping...
# Processing Record 5 of Set 9 | ostrovnoy
# Processing Record 6 of Set 9 | constitucion
# Processing Record 7 of Set 9 | landau
# Processing Record 8 of Set 9 | linjiang
# Processing Record 9 of Set 9 | kahului
# Processing Record 10 of Set 9 | bagotville
# Processing Record 11 of Set 9 | mangrol
# Processing Record 12 of Set 9 | kumasi
# Processing Record 13 of Set 9 | djambala
# Processing Record 14 of Set 9 | beringovskiy
# Processing Record 15 of Set 9 | fakel
# Processing Record 16 of Set 9 | dunedin
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | sao raimundo nonato
# Processing Record 19 of Set 9 | arti
# Processing Record 20 of Set 9 | misratah
# Processing Record 21 of Set 9 | krasnoselkup
# Processing Record 22 of Set 9 | abeche
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | tiksi
# Processing Record 25 of Set 9 | pokhara
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | camacha
# Processing Record 28 of Set 9 | hare bay
# Processing Record 29 of Set 9 | sault sainte marie
# Processing Record 30 of Set 9 | santa rosa
# Processing Record 31 of Set 9 | ous
# Processing Record 32 of Set 9 | kaeo
# Processing Record 33 of Set 9 | nanakuli
# Processing Record 34 of Set 9 | fort frances
# Processing Record 35 of Set 9 | bokajan
# Processing Record 36 of Set 9 | sofiyivka
# Processing Record 37 of Set 9 | anchorage
# Processing Record 38 of Set 9 | aykhal
# Processing Record 39 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 9 | mackenzie
# Processing Record 41 of Set 9 | bonavista
# Processing Record 42 of Set 9 | isangel
# Processing Record 43 of Set 9 | bambanglipuro
# Processing Record 44 of Set 9 | lokosovo
# Processing Record 45 of Set 9 | baykit
# Processing Record 46 of Set 9 | karpathos
# Processing Record 47 of Set 9 | sembe
# Processing Record 48 of Set 9 | santa maria
# Processing Record 49 of Set 9 | vestmannaeyjar
# Processing Record 50 of Set 9 | mafinga
# Processing Record 1 of Set 10 | atasu
# Processing Record 2 of Set 10 | sabha
# Processing Record 3 of Set 10 | dalbandin
# Processing Record 4 of Set 10 | tiarei
# Processing Record 5 of Set 10 | ipubi
# Processing Record 6 of Set 10 | parczew
# Processing Record 7 of Set 10 | gondar
# Processing Record 8 of Set 10 | zhanakorgan
# Processing Record 9 of Set 10 | ketchikan
# Processing Record 10 of Set 10 | baiao
# Processing Record 11 of Set 10 | arauco
# Processing Record 12 of Set 10 | ouesso
# Processing Record 13 of Set 10 | santiago del estero
# Processing Record 14 of Set 10 | vyartsilya
# Processing Record 15 of Set 10 | juegang
# Processing Record 16 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 10 | rudnogorsk
# Processing Record 18 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 10 | quelimane
# Processing Record 20 of Set 10 | lokoja
# Processing Record 21 of Set 10 | buin
# Processing Record 22 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | kirovskiy
# Processing Record 25 of Set 10 | pisco
# Processing Record 26 of Set 10 | watsa
# Processing Record 27 of Set 10 | naze
# Processing Record 28 of Set 10 | bryan
# Processing Record 29 of Set 10 | kota tinggi
# Processing Record 30 of Set 10 | narsaq
# Processing Record 31 of Set 10 | te anau
# Processing Record 32 of Set 10 | karratha
# Processing Record 33 of Set 10 | hami
# Processing Record 34 of Set 10 | bonthe
# Processing Record 35 of Set 10 | craig
# Processing Record 36 of Set 10 | faridan
# City not found. Skipping...
# Processing Record 37 of Set 10 | russkaya polyana
# Processing Record 38 of Set 10 | la peca
# Processing Record 39 of Set 10 | cheremkhovo
# Processing Record 40 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 41 of Set 10 | sirjan
# Processing Record 42 of Set 10 | ovalle
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | yekaterinovka
# Processing Record 45 of Set 10 | cayhagan
# Processing Record 46 of Set 10 | sri aman
# Processing Record 47 of Set 10 | bethel
# Processing Record 48 of Set 10 | lasa
# Processing Record 49 of Set 10 | languyan
# Processing Record 50 of Set 10 | tessalit
# Processing Record 1 of Set 11 | luganville
# Processing Record 2 of Set 11 | istra
# Processing Record 3 of Set 11 | goias
# Processing Record 4 of Set 11 | najran
# Processing Record 5 of Set 11 | shingu
# Processing Record 6 of Set 11 | kattivakkam
# Processing Record 7 of Set 11 | avanigadda
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | nakamura
# Processing Record 10 of Set 11 | visnes
# Processing Record 11 of Set 11 | marsh harbour
# Processing Record 12 of Set 11 | svobodnyy
# Processing Record 13 of Set 11 | susanville
# Processing Record 14 of Set 11 | isla mujeres
# Processing Record 15 of Set 11 | westport
# Processing Record 16 of Set 11 | imeni poliny osipenko
# Processing Record 17 of Set 11 | qaqortoq
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | san ramon
# Processing Record 20 of Set 11 | kloulklubed
# Processing Record 21 of Set 11 | chicama
# Processing Record 22 of Set 11 | grand baie
# Processing Record 23 of Set 11 | coquimbo
# Processing Record 24 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 11 | nampula
# Processing Record 26 of Set 11 | prince rupert
# Processing Record 27 of Set 11 | poum
# Processing Record 28 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 11 | muravlenko
# Processing Record 30 of Set 11 | bo phloi
# Processing Record 31 of Set 11 | inhambane
# Processing Record 32 of Set 11 | zavetnoye
# Processing Record 33 of Set 11 | itamaraca
# Processing Record 34 of Set 11 | pechora
# Processing Record 35 of Set 11 | teahupoo
# Processing Record 36 of Set 11 | guatire
# Processing Record 37 of Set 11 | valparaiso
# Processing Record 38 of Set 11 | unai
# Processing Record 39 of Set 11 | roswell
# Processing Record 40 of Set 11 | impfondo
# Processing Record 41 of Set 11 | muscat
# Processing Record 42 of Set 11 | talaya
# Processing Record 43 of Set 11 | atambua
# Processing Record 44 of Set 11 | hof
# Processing Record 45 of Set 11 | saryg-sep
# Processing Record 46 of Set 11 | jiangyou
# Processing Record 47 of Set 11 | mutoko
# Processing Record 48 of Set 11 | adrar
# Processing Record 49 of Set 11 | daokou
# Processing Record 50 of Set 11 | nanga eboko
# Processing Record 1 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 2 of Set 12 | pangkalanbuun
# Processing Record 3 of Set 12 | chipinge
# Processing Record 4 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 5 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 12 | askoy
# Processing Record 7 of Set 12 | acacoyagua
# Processing Record 8 of Set 12 | lazarev
# Processing Record 9 of Set 12 | byron bay
# Processing Record 10 of Set 12 | kiama
# Processing Record 11 of Set 12 | shimoda
# Processing Record 12 of Set 12 | siimusti
# Processing Record 13 of Set 12 | deer lake
# Processing Record 14 of Set 12 | almaznyy
# Processing Record 15 of Set 12 | serenje
# Processing Record 16 of Set 12 | geraldton
# Processing Record 17 of Set 12 | keetmanshoop
# Processing Record 18 of Set 12 | piacabucu
# Processing Record 19 of Set 12 | bilibino
# Processing Record 20 of Set 12 | halden
# Processing Record 21 of Set 12 | neiafu
# Processing Record 22 of Set 12 | leeuwarden
# Processing Record 23 of Set 12 | puerto maldonado
# Processing Record 24 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 12 | mlonggo
# Processing Record 26 of Set 12 | ahipara
# Processing Record 27 of Set 12 | thakurgaon
# Processing Record 28 of Set 12 | la ronge
# Processing Record 29 of Set 12 | noyabrsk
# Processing Record 30 of Set 12 | colares
# Processing Record 31 of Set 12 | miri
# Processing Record 32 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 12 | torbat-e jam
# Processing Record 34 of Set 12 | sharjah
# Processing Record 35 of Set 12 | zhanaozen
# Processing Record 36 of Set 12 | adelaide
# Processing Record 37 of Set 12 | shaunavon
# Processing Record 38 of Set 12 | kungurtug
# Processing Record 39 of Set 12 | aklavik
# Processing Record 40 of Set 12 | muroto
# Processing Record 41 of Set 12 | sitka
# Processing Record 42 of Set 12 | nenjiang
# Processing Record 43 of Set 12 | itaituba
# Processing Record 44 of Set 12 | ouargaye
# Processing Record 45 of Set 12 | aden
# Processing Record 46 of Set 12 | broken hill
# Processing Record 47 of Set 12 | catia la mar
# Processing Record 48 of Set 12 | tagusao
# Processing Record 49 of Set 12 | west bay
# Processing Record 50 of Set 12 | caala
# Processing Record 1 of Set 13 | yinchuan
# Processing Record 2 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 13 | tabou
# Processing Record 4 of Set 13 | hecun
# Processing Record 5 of Set 13 | palmas bellas
# Processing Record 6 of Set 13 | ust-barguzin
# Processing Record 7 of Set 13 | poronaysk
# Processing Record 8 of Set 13 | oyama
# Processing Record 9 of Set 13 | tabory
# Processing Record 10 of Set 13 | varangaon
# Processing Record 11 of Set 13 | eureka
# Processing Record 12 of Set 13 | odweyne
# Processing Record 13 of Set 13 | awbari
# Processing Record 14 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 13 | rockford
# Processing Record 16 of Set 13 | urusha
# Processing Record 17 of Set 13 | mahon
# Processing Record 18 of Set 13 | tazmalt
# Processing Record 19 of Set 13 | conde
# Processing Record 20 of Set 13 | boundiali
# Processing Record 21 of Set 13 | basco
# Processing Record 22 of Set 13 | vostok
# Processing Record 23 of Set 13 | ginir
# Processing Record 24 of Set 13 | lebork
# Processing Record 25 of Set 13 | mosquera
# Processing Record 26 of Set 13 | talavera de la reina
# Processing Record 27 of Set 13 | lata
# Processing Record 28 of Set 13 | gizo
# Processing Record 29 of Set 13 | brae
# Processing Record 30 of Set 13 | puro
# Processing Record 31 of Set 13 | aleppo
# Processing Record 32 of Set 13 | novooleksiyivka
# Processing Record 33 of Set 13 | zilair
# Processing Record 34 of Set 13 | manta
# Processing Record 35 of Set 13 | havoysund
# Processing Record 36 of Set 13 | bom jesus do itabapoana
# Processing Record 37 of Set 13 | jalu
# Processing Record 38 of Set 13 | hanyang
# Processing Record 39 of Set 13 | buraydah
# Processing Record 40 of Set 13 | srednekolymsk
# Processing Record 41 of Set 13 | srivardhan
# Processing Record 42 of Set 13 | clarence town
# Processing Record 43 of Set 13 | blagoveshchenka
# Processing Record 44 of Set 13 | alice springs
# Processing Record 45 of Set 13 | san jose
# Processing Record 46 of Set 13 | zalantun
# Processing Record 47 of Set 13 | tapah
# Processing Record 48 of Set 13 | ratnagiri
# Processing Record 49 of Set 13 | nizwa
# Processing Record 50 of Set 13 | talakan
# Processing Record 1 of Set 14 | northam
# Processing Record 2 of Set 14 | jingdezhen
# Processing Record 3 of Set 14 | oktyabrskiy
# Processing Record 4 of Set 14 | thinadhoo
# Processing Record 5 of Set 14 | gazli
# Processing Record 6 of Set 14 | alofi
# Processing Record 7 of Set 14 | indianola
# Processing Record 8 of Set 14 | soyo
# Processing Record 9 of Set 14 | sao joao da barra
# Processing Record 10 of Set 14 | polunochnoye
# Processing Record 11 of Set 14 | sokolo
# Processing Record 12 of Set 14 | lac du bonnet
# Processing Record 13 of Set 14 | seoul
# Processing Record 14 of Set 14 | calama
# Processing Record 15 of Set 14 | waddan
# Processing Record 16 of Set 14 | vila velha
# Processing Record 17 of Set 14 | whitehorse
# Processing Record 18 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 19 of Set 14 | vredendal
# Processing Record 20 of Set 14 | takapau
# Processing Record 21 of Set 14 | san alberto
# Processing Record 22 of Set 14 | suez
# Processing Record 23 of Set 14 | presidente medici
# Processing Record 24 of Set 14 | nanpiao
# Processing Record 25 of Set 14 | paamiut
# Processing Record 26 of Set 14 | samarai
# Processing Record 27 of Set 14 | jaguey grande
# Processing Record 28 of Set 14 | camana
# Processing Record 29 of Set 14 | bayanday
# Processing Record 30 of Set 14 | davila
# Processing Record 31 of Set 14 | leisure city
# Processing Record 32 of Set 14 | hambantota
# Processing Record 33 of Set 14 | ayagoz
# Processing Record 34 of Set 14 | gouyave
# Processing Record 35 of Set 14 | charlestown
# Processing Record 36 of Set 14 | babu
# Processing Record 37 of Set 14 | chinhoyi
# Processing Record 38 of Set 14 | waipawa
# Processing Record 39 of Set 14 | youhao
# Processing Record 40 of Set 14 | kudahuvadhoo
# Processing Record 41 of Set 14 | plettenberg bay
# Processing Record 42 of Set 14 | qasigiannguit
# Processing Record 43 of Set 14 | belogradcik
# City not found. Skipping...
# Processing Record 44 of Set 14 | olive branch
# Processing Record 45 of Set 14 | bulgan
# Processing Record 46 of Set 14 | palora
# Processing Record 47 of Set 14 | bahia blanca
# Processing Record 48 of Set 14 | semey
# Processing Record 49 of Set 14 | visby
# Processing Record 50 of Set 14 | palmer
# Processing Record 1 of Set 15 | punta umbria
# Processing Record 2 of Set 15 | kedrovyy
# Processing Record 3 of Set 15 | macaubas
# Processing Record 4 of Set 15 | cape coast
# Processing Record 5 of Set 15 | sarangani
# Processing Record 6 of Set 15 | fort collins
# Processing Record 7 of Set 15 | taltal
# Processing Record 8 of Set 15 | marathon
# Processing Record 9 of Set 15 | sonoita
# Processing Record 10 of Set 15 | bandar
# Processing Record 11 of Set 15 | tupik
# Processing Record 12 of Set 15 | sao felix do xingu
# Processing Record 13 of Set 15 | gerash
# Processing Record 14 of Set 15 | caucaia
# Processing Record 15 of Set 15 | itarema
# Processing Record 16 of Set 15 | nanzhang
# Processing Record 17 of Set 15 | makariv
# Processing Record 18 of Set 15 | puerto baquerizo moreno
# Processing Record 19 of Set 15 | zabaykalsk
# Processing Record 20 of Set 15 | chute-aux-outardes
# Processing Record 21 of Set 15 | nueva guinea
# Processing Record 22 of Set 15 | kapuskasing
# Processing Record 23 of Set 15 | blackwater
# Processing Record 24 of Set 15 | maragogi
# Processing Record 25 of Set 15 | preobrazheniye
# Processing Record 26 of Set 15 | tual
# Processing Record 27 of Set 15 | ust-maya
# Processing Record 28 of Set 15 | padang
# Processing Record 29 of Set 15 | nalut
# Processing Record 30 of Set 15 | tecoanapa
# Processing Record 31 of Set 15 | dukat
# Processing Record 32 of Set 15 | grand haven
# Processing Record 33 of Set 15 | roma
# Processing Record 34 of Set 15 | changli
# Processing Record 35 of Set 15 | khanpur
# Processing Record 36 of Set 15 | springbok
# Processing Record 37 of Set 15 | kuching
# Processing Record 38 of Set 15 | limbang
# Processing Record 39 of Set 15 | illapel
# Processing Record 40 of Set 15 | shache
# Processing Record 41 of Set 15 | caceres
# Processing Record 42 of Set 15 | paragominas
# Processing Record 43 of Set 15 | matara
# Processing Record 44 of Set 15 | monte alegre
# Processing Record 45 of Set 15 | huarmey
# Processing Record 46 of Set 15 | gander
# Processing Record 47 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 15 | sorland
# Processing Record 50 of Set 15 | patacamaya
# Processing Record 1 of Set 16 | raga
# Processing Record 2 of Set 16 | iquitos
# Processing Record 3 of Set 16 | coos bay
# Processing Record 4 of Set 16 | fort nelson
# Processing Record 5 of Set 16 | qiongshan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hede  33.7681  120.2517     38.08        50         100
# 1  Punta Arenas -53.1500  -70.9167     46.51        61          75
# 2       Cordoba -31.4135  -64.1811     75.18        65          20
# 3     Jamestown  42.0970  -79.2353     47.79        83           0
# 4         Banff  51.1762 -115.5698     -3.62        77         100
# 5      Bengkulu  -3.8004  102.2655     80.92        77          99
# 6        Mehamn  71.0357   27.8492     37.35        93          75
# 7  Puerto Ayora  -0.7393  -90.3518     70.56        89          45
# 8    Nanortalik  60.1432  -45.2371     31.59        83         100
# 9     Hithadhoo  -0.6000   73.0833     81.32        74         100
#
#    Wind Speed Country      Weather Description
# 0       16.80      CN          overcast clouds
# 1       23.02      CL            broken clouds
# 2       11.50      AR               few clouds
# 3       16.11      US                clear sky
# 4        1.14      CA          overcast clouds
# 5        4.54      ID          overcast clouds
# 6        9.22      NO  light intensity drizzle
# 7        8.99      EC         scattered clouds
# 8       10.92      GL          overcast clouds
# 9        5.70      MV          overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Weather Description']

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

#Rename the last column "Current Description" 
city_data_df.columns = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Current Description']

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hede      CN  33.7681  120.2517     38.08        50         100
# 1  Punta Arenas      CL -53.1500  -70.9167     46.51        61          75
# 2       Cordoba      AR -31.4135  -64.1811     75.18        65          20
# 3     Jamestown      US  42.0970  -79.2353     47.79        83           0
# 4         Banff      CA  51.1762 -115.5698     -3.62        77         100
#
#    Wind Speed Current Description
# 0       16.80     overcast clouds
# 1       23.02       broken clouds
# 2       11.50          few clouds
# 3       16.11           clear sky
# 4        1.14     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
